# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhu-2004-04/Deep-Learning/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build the Feed-Forward Neural Network
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images into a 1D array
    Dense(128, activation='relu'),  # Hidden layer with 128 neurons and ReLU activation
    Dense(64, activation='relu'),   # Hidden layer with 64 neurons and ReLU activation
    Dense(10, activation='softmax') # Output layer with 10 neurons for classification
])

# Compile the model
model.compile(optimizer=Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# Plot training history
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8743 - loss: 0.4437 - val_accuracy: 0.9634 - val_loss: 0.1182
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 5ms/step - accuracy: 0.9671 - loss: 0.1115 - val_accuracy: 0.9712 - val_loss: 0.0973
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9778 - loss: 0.0720 - val_accuracy: 0.9731 - val_loss: 0.0837
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9834 - loss: 0.0528 - val_accuracy: 0.9751 - val_loss: 0.0792
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9879 - loss: 0.0380 - val_accuracy: 0.9775 - val_loss: 0.0782
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9899 - loss: 0.0303 - val_accuracy: 0.9767 - val_loss: 0.0822
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9909 - loss: 0.0280 - val_accuracy: 0.9775 - val_loss: 0.0868
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9928 - loss: 0.0225 - val_accuracy: 0.9803 - val_loss: 0.0806
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9942 - loss: 0.0171 - val_accuracy: 0.9797 - val_loss: 0.0847
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9946 - loss: 0.0160 - val_accuracy: 0.9812 - val_loss: 0.0775
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9779 - loss: 0.0939
# Test accuracy: 0.9812

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build the Feed-Forward Neural Network
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images into a 1D array
    Dense(256, activation='relu'),  # Increased hidden layer size
    Dropout(0.2),  # Dropout to reduce overfitting
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax') # Output layer with 10 neurons for classification
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=15, batch_size=64, validation_data=(x_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# Plot training history
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8232 - loss: 0.5632 - val_accuracy: 0.9597 - val_loss: 0.1281
# Epoch 2/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9577 - loss: 0.1358 - val_accuracy: 0.9730 - val_loss: 0.0883
# Epoch 3/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9704 - loss: 0.0977 - val_accuracy: 0.9739 - val_loss: 0.0909
# Epoch 4/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9750 - loss: 0.0797 - val_accuracy: 0.9773 - val_loss: 0.0750
# Epoch 5/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9798 - loss: 0.0645 - val_accuracy: 0.9781 - val_loss: 0.0739
# Epoch 6/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9815 - loss: 0.0584 - val_accuracy: 0.9783 - val_loss: 0.0736
# Epoch 7/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9826 - loss: 0.0543 - val_accuracy: 0.9807 - val_loss: 0.0660
# Epoch 8/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9854 - loss: 0.0466 - val_accuracy: 0.9817 - val_loss: 0.0720
# Epoch 9/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9859 - loss: 0.0437 - val_accuracy: 0.9809 - val_loss: 0.0691
# Epoch 10/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9877 - loss: 0.0395 - val_accuracy: 0.9820 - val_loss: 0.0667
# Epoch 11/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9882 - loss: 0.0382 - val_accuracy: 0.9801 - val_loss: 0.0746
# Epoch 12/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9887 - loss: 0.0327 - val_accuracy: 0.9800 - val_loss: 0.0762
# Epoch 13/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9886 - loss: 0.0337 - val_accuracy: 0.9812 - val_loss: 0.0743
# Epoch 14/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9895 - loss: 0.0312 - val_accuracy: 0.9802 - val_loss: 0.0756
# Epoch 15/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9905 - loss: 0.0289 - val_accuracy: 0.9795 - val_loss: 0.0847
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9758 - loss: 0.0994
# Test accuracy: 0.9795

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build the Feed-Forward Neural Network
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images into a 1D array
    Dense(512, activation='relu'),  # Increased hidden layer size
    BatchNormalization(),  # Batch normalization to stabilize learning
    Dropout(0.3),  # Increased dropout to reduce overfitting
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax') # Output layer with 10 neurons for classification
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0005),  # Reduced learning rate for better convergence
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=20, batch_size=128, validation_data=(x_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {accuracy:.4f}")

# Plot training history
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.8205 - loss: 0.5821 - val_accuracy: 0.9628 - val_loss: 0.1191
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9568 - loss: 0.1400 - val_accuracy: 0.9720 - val_loss: 0.0904
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9685 - loss: 0.1014 - val_accuracy: 0.9746 - val_loss: 0.0770
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9739 - loss: 0.0837 - val_accuracy: 0.9778 - val_loss: 0.0706
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9766 - loss: 0.0757 - val_accuracy: 0.9779 - val_loss: 0.0701
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9817 - loss: 0.0566 - val_accuracy: 0.9805 - val_loss: 0.0616
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9830 - loss: 0.0513 - val_accuracy: 0.9808 - val_loss: 0.0634
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9858 - loss: 0.0455 - val_accuracy: 0.9806 - val_loss: 0.0689
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9861 - loss: 0.0415 - val_accuracy: 0.9818 - val_loss: 0.0623
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9871 - loss: 0.0391 - val_accuracy: 0.9830 - val_loss: 0.0585
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9885 - loss: 0.0360 - val_accuracy: 0.9817 - val_loss: 0.0628
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9886 - loss: 0.0340 - val_accuracy: 0.9820 - val_loss: 0.0625
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9889 - loss: 0.0325 - val_accuracy: 0.9825 - val_loss: 0.0622
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9903 - loss: 0.0287 - val_accuracy: 0.9821 - val_loss: 0.0698
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9907 - loss: 0.0285 - val_accuracy: 0.9839 - val_loss: 0.0619
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9910 - loss: 0.0254 - val_accuracy: 0.9822 - val_loss: 0.0594
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9921 - loss: 0.0239 - val_accuracy: 0.9832 - val_loss: 0.0599
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9914 - loss: 0.0246 - val_accuracy: 0.9843 - val_loss: 0.0568
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9911 - loss: 0.0257 - val_accuracy: 0.9838 - val_loss: 0.0627
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9916 - loss: 0.0243 - val_accuracy: 0.9837 - val_loss: 0.0611
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9799 - loss: 0.0748
# Test accuracy: 0.9837
