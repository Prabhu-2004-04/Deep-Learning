# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhu-2004-04/Deep-Learning/blob/main/pyexp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd

df = pd.read_csv("data.csv")  # Replace with actual filename
print(df.head())  # Show first few rows


# Build the single-layer perceptron model
model = Sequential([
    Dense(1, activation='sigmoid', input_shape=(2,))
])

# Compile the model
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=100, verbose=1)

# Evaluate the model
print("Final Predictions:")
print(model.predict(X))
# Out:
#          Date  Adj_Close     Close      High       Low      Open  Volume
# 0  1980-03-17   0.547989  0.893750  0.909375  0.893750  0.893750   26000
# 1  1980-03-18   0.557569  0.909375  0.909375  0.909375  0.909375    2000
# 2  1980-03-19   0.551821  0.900000  0.900000  0.900000  0.900000    2000
# 3  1980-03-20   0.551821  0.900000  0.900000  0.900000  0.900000       0
# 4  1980-03-21   0.551821  0.900000  0.900000  0.900000  0.900000    2000
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 0.5000 - loss: 0.7661
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 0.7658
# Epoch 3/100
# ...

# %%
df = pd.read_csv("data.csv")  # Replace with actual filename
print(df.head())  # Show first few rows

# Build the multi-layer perceptron model
model = Sequential([
    Dense(4, activation='relu', input_shape=(2,)),  # Hidden Layer
    Dense(1, activation='sigmoid')  # Output Layer
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=500, verbose=1)

# Evaluate the model
print("Final Predictions:")
print(model.predict(X))
# Out:
#          Date  Adj_Close     Close      High       Low      Open  Volume
# 0  1980-03-17   0.547989  0.893750  0.909375  0.893750  0.893750   26000
# 1  1980-03-18   0.557569  0.909375  0.909375  0.909375  0.909375    2000
# 2  1980-03-19   0.551821  0.900000  0.900000  0.900000  0.900000    2000
# 3  1980-03-20   0.551821  0.900000  0.900000  0.900000  0.900000       0
# 4  1980-03-21   0.551821  0.900000  0.900000  0.900000  0.900000    2000
# Epoch 1/500
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 0.8460
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.2500 - loss: 0.8441
# Epoch 3/500
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "data.csv"  # Change if needed
df = pd.read_csv(file_path, encoding="ISO-8859-1")  # Use ISO encoding to avoid errors

# Show basic info
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11293 entries, 0 to 11292
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       11293 non-null  object
#  1   Adj_Close  11293 non-null  float64
#  2   Close      11293 non-null  float64
#  3   High       11293 non-null  float64
#  4   Low        11293 non-null  float64
#  5   Open       11293 non-null  float64
#  6   Volume     11293 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 617.7+ KB
# None
#          Date  Adj_Close     Close      High       Low      Open  Volume
# 0  1980-03-17   0.547989  0.893750  0.909375  0.893750  0.893750   26000
# 1  1980-03-18   0.557569  0.909375  0.909375  0.909375  0.909375    2000
# 2  1980-03-19   0.551821  0.900000  0.900000  0.900000  0.900000    2000
# 3  1980-03-20   0.551821  0.900000  0.900000  0.900000  0.900000       0
# ...

# %%
df.hist(figsize=(12, 6), bins=20, edgecolor='black')
plt.suptitle("Feature Distribution", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x=df.index, y=df.iloc[:, 1])  # Change column index if needed
plt.title("Feature Trend Over Time")
plt.xlabel("Index")
plt.ylabel("Feature 1")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df.iloc[:, 0], y=df.iloc[:, 1])  # Adjust column indices
plt.title("Scatter Plot of Two Features")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values (0-255 → 0-1)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Flatten images (28x28 → 784 input neurons)
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# Function to plot training history
def plot_history(history, title):
    plt.figure(figsize=(12, 4))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# Function to visualize predictions
def visualize_predictions(model, title):
    predictions = model.predict(x_test[:10])  # Get predictions for 10 test images
    predicted_labels = np.argmax(predictions, axis=1)  # Convert one-hot to label

    plt.figure(figsize=(12, 4))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
        plt.title(f'Pred: {predicted_labels[i]}\nTrue: {y_test[i]}')
        plt.axis('off')
    plt.suptitle(f'{title} - Predictions')
    plt.show()

# =================== Single-Layer Perceptron (SLP) ===================

# Define the SLP model
slp_model = keras.Sequential([
    keras.layers.Dense(10, activation='softmax', input_shape=(784,))
])

# Compile the model
slp_model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
slp_history = slp_model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test), verbose=0)

# Plot training history
plot_history(slp_history, "Single-Layer Perceptron (SLP)")

# Visualize predictions
visualize_predictions(slp_model, "Single-Layer Perceptron (SLP)")

# =================== Multi-Layer Perceptron (MLP) ===================

# Define the MLP model
mlp_model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(784,)),  # Hidden Layer 1
    keras.layers.Dense(64, activation='relu'),  # Hidden Layer 2
    keras.layers.Dense(10, activation='softmax')  # Output Layer (10 classes)
])

# Compile the model
mlp_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
mlp_history = mlp_model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test), verbose=0)

# Plot training history
plot_history(mlp_history, "Multi-Layer Perceptron (MLP)")

# Visualize predictions
visualize_predictions(mlp_model, "Multi-Layer Perceptron (MLP)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values (0-255 → 0-1)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Flatten images (28x28 → 784 input neurons)
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# Function to plot training history
def plot_history(history, title):
    plt.figure(figsize=(12, 4))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()

# Define the optimized MLP model
mlp_model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(784,)),  # Hidden Layer 1
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(128, activation='relu'),  # Hidden Layer 2
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(64, activation='relu'),  # Hidden Layer 3
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),

    keras.layers.Dense(10, activation='softmax')  # Output Layer
])

# Compile the model
mlp_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001, decay=1e-6),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Implement Early Stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
mlp_history = mlp_model.fit(x_train, y_train, epochs=30, batch_size=64, validation_data=(x_test, y_test), callbacks=[early_stopping], verbose=1)

# Plot training history
plot_history(mlp_history, "Optimized Multi-Layer Perceptron (MLP)")

# Evaluate the model
test_loss, test_acc = mlp_model.evaluate(x_test, y_test)
print("Optimized MLP Test Accuracy:",test_acc)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.8270 - loss: 0.5542 - val_accuracy: 0.9585 - val_loss: 0.1294
# Epoch 2/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9492 - loss: 0.1682 - val_accuracy: 0.9699 - val_loss: 0.0947
# Epoch 3/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9598 - loss: 0.1297 - val_accuracy: 0.9752 - val_loss: 0.0800
# Epoch 4/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9660 - loss: 0.1097 - val_accuracy: 0.9762 - val_loss: 0.0751
# Epoch 5/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9698 - loss: 0.0975 - val_accuracy: 0.9802 - val_loss: 0.0659
# Epoch 6/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9737 - loss: 0.0852 - val_accuracy: 0.9786 - val_loss: 0.0700
# Epoch 7/30
# ...
