# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhu-2004-04/Deep-Learning/blob/main/pyexp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python numpy matplotlib scikit-image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = cv2.imread("image.png")  # Replace with your image file
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB

# Display the image
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.title("Grayscale Image")
plt.show()

# %%
edges = cv2.Canny(gray, 100, 200)

plt.imshow(edges, cmap="gray")
plt.axis("off")
plt.title("Canny Edge Detection")
plt.show()

# %%
from skimage.feature import hog

# Compute HOG features
hog_features, hog_image = hog(gray, pixels_per_cell=(8, 8),
                              cells_per_block=(2, 2), visualize=True)

plt.imshow(hog_image, cmap="gray")
plt.axis("off")
plt.title("HOG Feature Representation")
plt.show()

# %%
orb = cv2.ORB_create()
keypoints = orb.detect(gray, None)
image_with_keypoints = cv2.drawKeypoints(image, keypoints, None, color=(0,255,0))

plt.imshow(image_with_keypoints)
plt.axis("off")
plt.title("ORB Keypoints")
plt.show()
